# %%
import wrds

# %%
db = wrds.Connection()
# Out:
# WRDS recommends setting up a .pgpass file.
# Created .pgpass file successfully.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %%
db.create_pgpass_file()

# %%
db.list_libraries().sort()

# %%
print(db.list_libraries())
# Out:
# ['aha_sample', 'ahasamp', 'audit', 'audit_audit_comp', 'audit_common', 'audit_corp_legal', 'auditsmp', 'auditsmp_all', 'bank', 'bank_all', 'bank_premium_samp', 'banksamp', 'block', 'block_all', 'boardex', 'boardex_na', 'boardex_row', 'boardex_trial', 'boardsmp', 'bvd', 'bvd_amadeus_trial', 'bvd_bvdbankf', 'bvd_bvdbankf_trial', 'bvd_orbis_large', 'bvd_orbis_medium', 'bvd_orbis_small', 'bvd_orbis_trial', 'bvdsamp', 'calcbench_trial', 'calcbnch', 'cboe', 'cboe_all', 'cboe_sample', 'cboesamp', 'ciq', 'ciq_capstrct', 'ciq_common', 'ciq_keydev', 'ciq_pplintel', 'ciq_transactions', 'ciqsamp', 'ciqsamp_capstrct', 'ciqsamp_common', 'ciqsamp_keydev', 'ciqsamp_pplintel', 'ciqsamp_ratings', 'ciqsamp_transactions', 'ciqsamp_transcripts', 'cisdmsmp', 'columnar', 'comp', 'comp_execucomp', 'comp_global', 'comp_global_daily', 'comp_na_annual_all', 'comp_na_daily_all', 'comp_na_monthly_all', 'compa', 'compg', 'compm', 'compsamp', 'compsamp_all', 'compsamp_snapshot', 'contrib', 'contrib_as_filed_financ
# ...

# %%
print(db.list_tables(library='crsp'))
# Out:
# ['acti', 'asia', 'asib', 'asic', 'asio', 'asix', 'bmdebt', 'bmheader', 'bmpaymts', 'bmquotes', 'bmyield', 'bndprt06', 'bndprt12', 'bxcalind', 'bxdlyind', 'bxmthind', 'bxquotes', 'bxyield', 'cap', 'ccm_lookup', 'ccm_qvards', 'ccmxpf_linktable', 'ccmxpf_lnkhist', 'ccmxpf_lnkrng', 'ccmxpf_lnkused', 'comphead', 'comphist', 'compmaster', 'contact_info', 'core', 'crsp_cik_map', 'crsp_daily_data', 'crsp_header', 'crsp_monthly_data', 'crsp_names', 'crsp_portno_map', 'crsp_ziman_daily_index', 'crsp_ziman_monthly_index', 'cs20yr', 'cs5yr', 'cs90d', 'cst_hist', 'daily_nav', 'daily_nav_ret', 'daily_returns', 'dividends', 'dport1', 'dport2', 'dport3', 'dport4', 'dport5', 'dport6', 'dport7', 'dport8', 'dport9', 'dsbc', 'dsbo', 'dse', 'dse62', 'dse62delist', 'dse62dist', 'dse62exchdates', 'dse62names', 'dse62nasdin', 'dse62shares', 'dseall', 'dseall62', 'dsedelist', 'dsedist', 'dseexchdates', 'dsenames', 'dsenasdin', 'dseshares', 'dsf', 'dsf62', 'dsf62_v2', 'dsf_v2', 'dsfhdr', 'dsfhdr62', 'dsi', 'd
# ...

# %%
print(db.list_tables(library='optionm'))
# Out:
# ['borrate1996', 'borrate1997', 'borrate1998', 'borrate1999', 'borrate2000', 'borrate2001', 'borrate2002', 'borrate2003', 'borrate2004', 'borrate2005', 'borrate2006', 'borrate2007', 'borrate2008', 'borrate2009', 'borrate2010', 'borrate2011', 'borrate2012', 'borrate2013', 'borrate2014', 'borrate2015', 'borrate2016', 'borrate2017', 'borrate2018', 'borrate2019', 'borrate2020', 'borrate2021', 'borrate2022', 'borrate2023', 'country', 'currency', 'distrd', 'distribution', 'distribution_projection', 'distrprojd1996', 'distrprojd1997', 'distrprojd1998', 'distrprojd1999', 'distrprojd2000', 'distrprojd2001', 'distrprojd2002', 'distrprojd2003', 'distrprojd2004', 'distrprojd2005', 'distrprojd2006', 'distrprojd2007', 'distrprojd2008', 'distrprojd2009', 'distrprojd2010', 'distrprojd2011', 'distrprojd2012', 'distrprojd2013', 'distrprojd2014', 'distrprojd2015', 'distrprojd2016', 'distrprojd2017', 'distrprojd2018', 'distrprojd2019', 'distrprojd2020', 'distrprojd2021', 'distrprojd2022', 'distrprojd2023
# ...

# %%
print(db.list_tables(library='optionm_all'))
# Out:
# ['borrate1996', 'borrate1997', 'borrate1998', 'borrate1999', 'borrate2000', 'borrate2001', 'borrate2002', 'borrate2003', 'borrate2004', 'borrate2005', 'borrate2006', 'borrate2007', 'borrate2008', 'borrate2009', 'borrate2010', 'borrate2011', 'borrate2012', 'borrate2013', 'borrate2014', 'borrate2015', 'borrate2016', 'borrate2017', 'borrate2018', 'borrate2019', 'borrate2020', 'borrate2021', 'borrate2022', 'borrate2023', 'distrd', 'distrprojd1996', 'distrprojd1997', 'distrprojd1998', 'distrprojd1999', 'distrprojd2000', 'distrprojd2001', 'distrprojd2002', 'distrprojd2003', 'distrprojd2004', 'distrprojd2005', 'distrprojd2006', 'distrprojd2007', 'distrprojd2008', 'distrprojd2009', 'distrprojd2010', 'distrprojd2011', 'distrprojd2012', 'distrprojd2013', 'distrprojd2014', 'distrprojd2015', 'distrprojd2016', 'distrprojd2017', 'distrprojd2018', 'distrprojd2019', 'distrprojd2020', 'distrprojd2021', 'distrprojd2022', 'distrprojd2023', 'exchgd', 'fwdprd1996', 'fwdprd1997', 'fwdprd1998', 'fwdprd1999
# ...

# %%
table_info = db.describe_table(library='crsp', table='msf')
table_info
# Out:
# Approximately 5037353 rows in crsp.msf.
#         name  nullable              type  \
# 0      cusip      True        VARCHAR(8)
# 1     permno      True           INTEGER
# 2     permco      True           INTEGER
# 3     issuno      True           INTEGER
# 4      hexcd      True          SMALLINT
# 5     hsiccd      True           INTEGER
# 6       date      True              DATE
# 7      bidlo      True    NUMERIC(11, 5)
# 8      askhi      True    NUMERIC(11, 5)
# 9        prc      True    NUMERIC(11, 5)
# 10       vol      True    NUMERIC(10, 0)
# 11       ret      True    NUMERIC(10, 6)
# 12       bid      True    NUMERIC(11, 5)
# 13       ask      True    NUMERIC(11, 5)
# 14    shrout      True  DOUBLE PRECISION
# 15    cfacpr      True  DOUBLE PRECISION
# 16   cfacshr      True  DOUBLE PRECISION
# 17    altprc      True    NUMERIC(11, 5)
# 18    spread      True    NUMERIC(10, 5)
# 19  altprcdt      True              DATE
# 20      retx      True    NUMERIC(10, 6)
#
# ...

# %%
db.get_table(library='crsp', table='msf', obs=10)
# Out:
#       cusip  permno  permco  issuno  hexcd  hsiccd        date     bidlo  \
# 0  68391610   10000    7952   10396      3    3990  1985-12-31      None
# 1  68391610   10000    7952   10396      3    3990  1986-01-31  -2.50000
# 2  68391610   10000    7952   10396      3    3990  1986-02-28  -3.25000
# 3  68391610   10000    7952   10396      3    3990  1986-03-31  -3.25000
# 4  68391610   10000    7952   10396      3    3990  1986-04-30  -4.00000
# 5  68391610   10000    7952   10396      3    3990  1986-05-30  -3.06250
# 6  68391610   10000    7952   10396      3    3990  1986-06-30  -2.90625
# 7  68391610   10000    7952   10396      3    3990  1986-07-31  -2.59375
# 8  68391610   10000    7952   10396      3    3990  1986-08-29  -1.03125
# 9  68391610   10000    7952   10396      3    3990  1986-09-30  -0.96875
#
#       askhi       prc  ...        ret   bid   ask  shrout  cfacpr  cfacshr  \
# 0      None      None  ...       None  None  None     NaN     NaN      NaN
# ...

# %%
ti_1 = db.describe_table(library='crsp', table='dsf')
ti_1
# Out:
# Approximately 105258384 rows in crsp.dsf.
#        name  nullable              type  \
# 0     cusip      True        VARCHAR(8)
# 1    permno      True           INTEGER
# 2    permco      True           INTEGER
# 3    issuno      True           INTEGER
# 4     hexcd      True          SMALLINT
# 5    hsiccd      True           INTEGER
# 6      date      True              DATE
# 7     bidlo      True    NUMERIC(11, 5)
# 8     askhi      True    NUMERIC(11, 5)
# 9       prc      True    NUMERIC(11, 5)
# 10      vol      True    NUMERIC(10, 0)
# 11      ret      True    NUMERIC(10, 6)
# 12      bid      True    NUMERIC(11, 5)
# 13      ask      True    NUMERIC(11, 5)
# 14   shrout      True  DOUBLE PRECISION
# 15   cfacpr      True  DOUBLE PRECISION
# 16  cfacshr      True  DOUBLE PRECISION
# 17  openprc      True    NUMERIC(11, 5)
# 18   numtrd      True           INTEGER
# 19     retx      True    NUMERIC(10, 6)
#
#                                     comment
# ...

# %%
ti_2 = db.describe_table(library='optionm', table='option_price_2005')
ti_2
# Out:
# Approximately 18965492 rows in optionm.option_price_2005.
#                  name  nullable              type            comment
# 0          securityid      True    NUMERIC(11, 0)         SecurityID
# 1            optionid      True    NUMERIC(11, 0)           OptionID
# 2            exchange      True    NUMERIC(11, 0)           Exchange
# 3            currency      True    NUMERIC(11, 0)           Currency
# 4                 bid      True  DOUBLE PRECISION                Bid
# 5       underlyingbid      True  DOUBLE PRECISION      UnderlyingBid
# 6                 ask      True  DOUBLE PRECISION                Ask
# 7       underlyingask      True  DOUBLE PRECISION      UnderlyingAsk
# 8                last      True  DOUBLE PRECISION               Last
# 9      underlyinglast      True  DOUBLE PRECISION     UnderlyingLast
# 10  impliedvolatility      True  DOUBLE PRECISION  ImpliedVolatility
# 11              delta      True  DOUBLE PRECISION              Delta
# ...

# %%
ti_3 = db.describe_table(library='optionm', table='option')
ti_3
# Out:
# Approximately 16231482 rows in optionm.option.
#                name  nullable            type          comment
# 0        securityid      True  NUMERIC(11, 0)       SecurityID
# 1          optionid      True  NUMERIC(11, 0)         OptionID
# 2          exchange      True  NUMERIC(11, 0)         Exchange
# 3       description      True    VARCHAR(255)      Description
# 4          currency      True  NUMERIC(11, 0)         Currency
# 5            strike      True  NUMERIC(20, 0)           Strike
# 6           callput      True      VARCHAR(1)          CallPut
# 7   underlyingvalor      True  NUMERIC(11, 0)  UnderlyingVALOR
# 8      contractsize      True  NUMERIC(11, 0)     ContractSize
# 9       optionstyle      True  NUMERIC(11, 0)      OptionStyle
# 10    exercisestyle      True      VARCHAR(1)    ExerciseStyle
# 11       expiration      True            DATE             None
